# %% [markdown]
# <a href="https://colab.research.google.com/github/RAVIKANTH55-rgb/ipl-data-analysis/blob/main/IPL_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
top_batsmen = df.groupby("batter")["runs_batter"].sum().sort_values(ascending=False).head(10)
top_batsmen.plot(kind="barh", title="Top 10 Batsmen (Total Runs)")
# Out:
# <Axes: title={'center': 'Top 10 Batsmen (Total Runs)'}, ylabel='batter'>

# %% [markdown]
# # New Section

# %%
top_bowlers = df.groupby("bowler")["bowler_wicket"].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind="barh", title="Top 10 Bowlers (Wickets)")
# Out:
# <Axes: title={'center': 'Top 10 Bowlers (Wickets)'}, ylabel='bowler'>

# %%
toss_wins = df["toss_winner"].value_counts().head(10)
toss_wins.plot(kind="bar", title="Toss Wins by Teams")
# Out:
# <Axes: title={'center': 'Toss Wins by Teams'}, xlabel='toss_winner'>

# %%
venue_counts = df["venue"].value_counts().head(10)
venue_counts.plot(kind="barh", title="Top 10 IPL Venues")
# Out:
# <Axes: title={'center': 'Top 10 IPL Venues'}, ylabel='venue'>

# %%
yearly_matches = df["year"].value_counts().sort_index()
yearly_matches.plot(kind="line", marker="o", title="Matches per Year")
# Out:
# <Axes: title={'center': 'Matches per Year'}, xlabel='year'>
